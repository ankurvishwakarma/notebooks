# %% [markdown]
# # PlanGrid Lost Opportunities Analysis
# Ankur Vishwakarma
# November 25, 2020

# %%
# import everything 

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import snowflake.connector as snow

# %%
# write function to get data from snowflake

def query_snowflake(sql_query):
    '''Runs the supplied query and returns a Pandas dataframe.'''
    
    ctx = snow.connect( 
        account   = os.getenv('snowflake_account'),
        user      = os.getenv('snowflake_username'),
        password  = os.getenv('snowflake_password'),
        warehouse = os.getenv('snowflake_warehouse'),
        role      = os.getenv('snowflake_role')
    )

    cs = ctx.cursor()

    try:
        cs.execute(sql_query)
        data = pd.DataFrame(cs.fetchall())
        data.columns = [x[0] for x in cs.description]
    finally:
        cs.close()

    ctx.close()
    
    return data

# %%
# sql query

sql_query = """
    with
    post_merger_opps as (
        select o.*
        from pg_prod_db.salesforce.opportunity o
        where o.created_date >= '2020-02-01'
        and (PLAN_GRID_REA_C > 0 
        or (type = 'Renewal' and renewal_type_c = 'PlanGrid'))
    ),
    
    pre_merger_opps as(
        select o.*      
        from pg_prod_db.salesforce.opportunity o
        where o.created_date < '2020-02-01'
        and o.assemble_ext_id_c is null 
        and o.bc_ext_id_c is null 
    ),
    
    unioned as (
        select * from post_merger_opps
        union
        select * from pre_merger_opps
    ),
    
    adsk_quarters as (
        select 
            date, 
            CONCAT(RIGHT(QUARTER_ADSK_TEXT_LONG, 4), '-', LEFT(QUARTER_ADSK_TEXT_LONG, 2)) as QUARTER_ADSK_TEXT_LONG
        from bc_prod_db.analytics.fct_calendar
    ),
    
    add_dates as (
        select 
            u.*,
            d1.QUARTER_ADSK_TEXT_LONG as CREATED_QUARTER,
            d2.QUARTER_ADSK_TEXT_LONG as CLOSE_QUARTER
        from unioned u 
        left join adsk_quarters d1 on u.created_date::date = d1.date
        left join adsk_quarters d2 on u.close_date::date = d2.date
    ),
    
    final as (
        select 
            case 
                /* updated 11/24/20 */
                when o.currency_iso_code = 'AED' then 0.272294
                when o.currency_iso_code = 'AUD' then 0.735767
                when o.currency_iso_code = 'CAD' then 0.769167
                when o.currency_iso_code = 'EUR' then 1.18859
                when o.currency_iso_code = 'GBP' then 1.33535
                when o.currency_iso_code = 'HKD' then 0.129004
                when o.currency_iso_code = 'INR' then 0.0135074
                when o.currency_iso_code = 'JPY' then 0.00956707
                when o.currency_iso_code = 'SGD' then 0.745197
                when o.currency_iso_code = 'USD' then 1.00
                end as currency_conversion,
            case 
                when o.Finance_Confirmed_c is null or o.Finance_Confirmed_c = 0
                then o.reps_calculated_amount_c
                else o.Finance_Confirmed_c
                end as reporting_gross_new_arr,
            reporting_gross_new_arr*currency_conversion as reporting_gross_new_arr_usd,
            reporting_gross_new_arr_usd*(o.probability/100.0) as weighted_rea_usd,
            o.*
        from add_dates o
    )
    
    select *
    from final;
"""

# %%
# get data from snowflake

df = query_snowflake(sql_query)

# %%
# shape of returned data

df_shape = df.shape
print('{:,} rows and {:,} columns returned.'.format(df_shape[0], df_shape[1]))
# Out:
# 176,248 rows and 486 columns returned.

# %%
# group opps by type

df['TYPE'].value_counts()
# Out:
# New                         66015
# Renewal                     43800
# Console Add-On              35707
# AddOn                       22540
# Upsell                       4015
# Consulting Services          2046
# Combo                         591
# Pilot - Unpaid                357
# Other                         235
# Token                         225
# Combo renewal and upsell      180
# New Business                    7
# Partner                         3
# BETA                            2
# Pilot - Paid                    2
# Same Source                     1
# Advisor                         1
# New customer                    1
# Name: TYPE, dtype: int64

# %%
# current stage (by percentage) of new opps

df[df['TYPE'] == 'New']['STAGE_NAME'].value_counts(normalize = True)
# Out:
# Closed Lost           0.622586
# Booked                0.321063
# Closed Won            0.024010
# Stage 2               0.019253
# Stage 3               0.005802
# Stage 1               0.004378
# Stage 4               0.001878
# Stage 5               0.000909
# Received from BD      0.000091
# Lead                  0.000015
# Proposal Delivered    0.000015
# Name: STAGE_NAME, dtype: float64

# %%
# preview 

df.head()
# Out:
#   CURRENCY_CONVERSION REPORTING_GROSS_NEW_ARR REPORTING_GROSS_NEW_ARR_USD  \
# 0          1.00000000                  645.00              645.0000000000
# 1          1.00000000                  397.80              397.8000000000
# 2          1.00000000                 1959.99             1959.9900000000
# 3          1.00000000                  200.00              200.0000000000
# 4          1.00000000                  601.80              601.8000000000
#
#    WEIGHTED_REA_USD                  ID  IS_DELETED          ACCOUNT_ID  \
# 0            645.00  0060W0000130KFbQAM       False  001d000001h3FINAA2
# 1            397.80  0060W0000130h54QAA       False  0010W00002TFDgTQAX
# 2           1959.99  0060W0000130ZkWQAU       False  001d000001txCNCAA2
# 3            200.00  0060W0000130RBYQA2       False  001d000001nS3IsAAK
# 4            601.80  0060W0000130ajQQAQ       False  001d000001qi4VpAAI
#
#                                      NAME DESCRIPTION STAGE_NAME  ...  \
# 0  AC Add-On - WHITINGTUR-0078 - 07-31-20        None     Booked  ...
# 1  AC Add-On - GSCFIRES-356775 - 07-31-20        None     Booked  ...
# 2  AC Add-On - SCHOLESE-021092 - 07-31-20        None     Booked  ...
# 3  AC Add-On - THOMPSON-013405 - 07-31-20        None     Booked  ...
# 4  AC Add-On - STAFFORD-014609 - 07-31-20        None     Booked  ...
#
#   PYPE_AE_C  PYPE_REA_C DISTRICT_MANAGER_APPROVAL_C  \
# 0      None        None                        None
# 1      None        None                        None
# 2      None        None                        None
# 3      None        None                        None
# 4      None        None                        None
#
#   PRIORITY_ACCOUNT_HANDOFF_REASON_C OTHER_HANDOFF_REASON_C  \
# 0                              None                   None
# 1                              None                   None
# 2                              None                   None
# 3                              None                   None
# 4                              None                   None
#
#   WORKFLOW_BENCHMARKING_TOOL_C NEXT_SURVEY_DATE_C  SEND_QUALTRICS_NPSSURVEY_C  \
# 0                         None               None                        None
# 1                         None               None                        None
# 2                         None               None                        None
# 3                         None               None                        None
# 4                         None               None                        None
#
#    CREATED_QUARTER CLOSE_QUARTER
# 0          2021-Q2       2021-Q2
# 1          2021-Q2       2021-Q2
# 2          2021-Q2       2021-Q2
# 3          2021-Q2       2021-Q2
# 4          2021-Q2       2021-Q2
#
# [5 rows x 486 columns]

# %%
# group ACV by quarter

acv_by_quarter = pd.DataFrame(df[df['CLOSE_DATE'] <= pd.Timestamp.today()].
                              groupby(by = 'CLOSE_QUARTER')['REPORTING_GROSS_NEW_ARR_USD'].
                              sum())

acv_by_quarter.reset_index(inplace = True)
acv_by_quarter['REPORTING_GROSS_NEW_ARR_USD'] = acv_by_quarter['REPORTING_GROSS_NEW_ARR_USD'].astype(float)
acv_by_quarter
# Out:
#    CLOSE_QUARTER  REPORTING_GROSS_NEW_ARR_USD
# 0        2015-Q4                 6.227250e+05
# 1        2016-Q1                 2.922204e+06
# 2        2016-Q2                 3.277571e+06
# 3        2016-Q3                 4.354925e+06
# 4        2016-Q4                 5.327659e+06
# 5        2017-Q1                 8.735271e+06
# 6        2017-Q2                 8.413804e+06
# 7        2017-Q3                 8.770562e+06
# 8        2017-Q4                 1.003246e+07
# 9        2018-Q1                 9.679344e+06
# 10       2018-Q2                 9.136495e+06
# 11       2018-Q3                 1.045756e+07
# 12       2018-Q4                 1.291074e+07
# 13       2019-Q1                 1.372756e+07
# 14       2019-Q2                 1.743228e+07
# 15       2019-Q3                 1.545317e+07
# 16       2019-Q4                 1.644753e+07
# 17       2020-Q1                 1.658019e+07
# 18       2020-Q2                 1.834788e+07
# 19       2020-Q3                 1.723906e+07
# 20       2020-Q4                 2.059413e+07
# 21       2021-Q1                 1.909892e+07
# 22       2021-Q2                 1.671070e+07
# 23       2021-Q3                 2.403272e+07
# 24       2021-Q4                 7.223857e+06

# %%
# plot ACV by quarter

ind = np.arange(len(acv_by_quarter['CLOSE_QUARTER']))
width = 0.8

fig, ax = plt.subplots(figsize = (12, 8))
rects1 = ax.bar(ind - width/2, 
                acv_by_quarter['REPORTING_GROSS_NEW_ARR_USD'], 
                width, 
                label='Reporting Gross New ARR (USD)'
               )

ax.set_ylabel('Reporting Gross New ARR (USD)')
ax.set_title('Quarterly ARR')
ax.set_xticks(ind)
ax.set_xticklabels(acv_by_quarter['CLOSE_QUARTER'], rotation = 90)
# ax.legend()

def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom')


# autolabel(rects1, 'center')

plt.show()
